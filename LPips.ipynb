# %% [markdown]
# <a href="https://colab.research.google.com/github/pdanahy/ML-public/blob/main/LPips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# CD to Directory

# %%
# %ls
# %cd /content/drive/MyDrive/LPips
# Out:
# drive/  sample_data/
# /content/drive/MyDrive/LPips

# %% [markdown]
# Run OPENCV Univform TILE Decomposition

# %%
# !python split_uniformtile.py --path /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsBarn0006_M.jpg --window 64

# %% [markdown]
# Run OPENCV QUADTREE Decomposition

# %%
# !python split_quadtreetile.py --path /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsUtility0025_M.jpg --store True
# Out:
# path: /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsUtility0025_M.jpg
# store: True
# TexturesCom_BuildingsUtility0025_M.jpg

# %% [markdown]
# Run LPips Substitution Uniform

# %%
# !python lpips_2dirs.py -d0 /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsUtility0025_M -d1 /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsBarn0006_M/tiled_64 --use_gpu
# Out:
# 2022-01-09 20:35:13.361184: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Found GPU at: /device:GPU:0
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /content/drive/MyDrive/LPips/lpips/weights/v0.1/alex.pth
#
# ------- RUNNING IMAGE LOOPS --------
# Find Files Here:./imgs/substituted_/TexturesCom_BuildingsUtility0025_M
#
# Elapsed Time per Image:22.19202971458435
# Elapsed Time per Image:11.511867046356201
# Elapsed Time per Image:11.376013040542603
# Elapsed Time per Image:11.341540813446045
# Elapsed Time per Image:11.326194763183594
# Elapsed Time per Image:11.272987127304077
# Elapsed Time per Image:11.657023191452026
# Elapsed Time per Image:11.429458141326904
# Elapsed Time per Image:11.371612548828125
# Elapsed Time per Image:11.317293167114258
# ...

# %% [markdown]
# Run OPENCV TILING

# %%
# !python uniformtile_compose.py --path 'PATH TO SUBSTITUTED DIRECTORY' --window 64 --ref 'PATH TO REFERENCE IMAGE'

# %% [markdown]
# Run QUADTREE TILING from Node List

# %%
# !python quadtreetile_compose.py --path /content/drive/MyDrive/LPips/imgs/substituted_/TexturesCom_BuildingsUtility0025_M --ref /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsUtility0025_M.jpg
# Out:
# path: /content/drive/MyDrive/LPips/imgs/substituted_/TexturesCom_BuildingsUtility0025_M
# ref: /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsUtility0025_M.jpg

# %% [markdown]
# Run OPENCV SEGMENTATION

# %%
# !python segment.py --input /content/drive/MyDrive/LPips/imgs/TexturesCom_BuildingsBarn0006_M.jpg --threshold 0.06

# %% [markdown]
# Download Image/SAVE TO GOOGLE DRIVE
